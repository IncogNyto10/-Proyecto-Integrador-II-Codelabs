# %%
# !pip install tensorflow keras numpy opencv-python matplotlib
import numpy as np  
from tensorflow.keras.models import Sequential  
from tensorflow.keras.layers import Dense, Input
# Out:
# Requirement already satisfied: tensorflow in /home/lord/Desktop/-Proyecto-Integrador-II-Codelabs/.venv/lib/python3.12/site-packages (2.20.0)
# Requirement already satisfied: keras in /home/lord/Desktop/-Proyecto-Integrador-II-Codelabs/.venv/lib/python3.12/site-packages (3.12.0)
# Requirement already satisfied: numpy in /home/lord/Desktop/-Proyecto-Integrador-II-Codelabs/.venv/lib/python3.12/site-packages (2.2.6)
# Requirement already satisfied: opencv-python in /home/lord/Desktop/-Proyecto-Integrador-II-Codelabs/.venv/lib/python3.12/site-packages (4.12.0.88)
# Requirement already satisfied: matplotlib in /home/lord/Desktop/-Proyecto-Integrador-II-Codelabs/.venv/lib/python3.12/site-packages (3.10.7)
# Requirement already satisfied: absl-py>=1.0.0 in /home/lord/Desktop/-Proyecto-Integrador-II-Codelabs/.venv/lib/python3.12/site-packages (from tensorflow) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in /home/lord/Desktop/-Proyecto-Integrador-II-Codelabs/.venv/lib/python3.12/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /home/lord/Desktop/-Proyecto-Integrador-II-Codelabs/.venv/lib/python3.12/site-packages (from tensorflow) (25.9.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /home/lord/Desktop/-Proyecto-Integrador-II-Codelabs/.venv/lib/python3.12/site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /home/lord/Desktop/-Proyecto-Integrador-II-Codelabs/.venv/lib/python3.12/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/lord/Desktop/-Proyecto-Integrador-II-Codelabs/.venv/lib/python3.12/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /home/lord/Desktop/-Proyecto-Integrador-II-Codelabs/.venv/lib/python3.12/site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /home/lord/Desktop/-Proyecto-Integrador-II-Codelabs/.venv/lib/python3.12/site-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf>=5.28.0 in /home/lord/Desktop/-Proyecto-Integrador-II-Codelabs/.venv/lib/python3.12/site-packages (from tensorflow) (6.33.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/lord/Desktop/-Proyecto-Integrador-II-Codelabs/.venv/lib/python3.12/site-packages (from tensorflow) (2.32.5)
# Requirement already satisfied: setuptools in /home/lord/Desktop/-Proyecto-Integrador-II-Codelabs/.venv/lib/python3.12/site-packages (from tensorflow) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in /home/lord/Desktop/-Proyecto-Integrador-II-Codelabs/.venv/lib/python3.12/site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/lord/Desktop/-Proyecto-Integrador-II-Codelabs/.venv/lib/python3.12/site-packages (from tensorflow) (3.2.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /home/lord/Desktop/-Proyecto-Integrador-II-Codelabs/.venv/lib/python3.12/site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /home/lord/Desktop/-Proyecto-Integrador-II-Codelabs/.venv/lib/python3.12/site-packages (from tensorflow) (2.0.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/lord/Desktop/-Proyecto-Integrador-II-Codelabs/.venv/lib/python3.12/site-packages (from tensorflow) (1.76.0)
# Requirement already satisfied: tensorboard~=2.20.0 in /home/lord/Desktop/-Proyecto-Integrador-II-Codelabs/.venv/lib/python3.12/site-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: h5py>=3.11.0 in /home/lord/Desktop/-Proyecto-Integrador-II-Codelabs/.venv/lib/python3.12/site-packages (from tensorflow) (3.15.1)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /home/lord/Desktop/-Proyecto-Integrador-II-Codelabs/.venv/lib/python3.12/site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/lord/Desktop/-Proyecto-Integrador-II-Codelabs/.venv/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/lord/Desktop/-Proyecto-Integrador-II-Codelabs/.venv/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/lord/Desktop/-Proyecto-Integrador-II-Codelabs/.venv/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/lord/Desktop/-Proyecto-Integrador-II-Codelabs/.venv/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (2025.11.12)
# Requirement already satisfied: markdown>=2.6.8 in /home/lord/Desktop/-Proyecto-Integrador-II-Codelabs/.venv/lib/python3.12/site-packages (from tensorboard~=2.20.0->tensorflow) (3.10)
# Requirement already satisfied: pillow in /home/lord/Desktop/-Proyecto-Integrador-II-Codelabs/.venv/lib/python3.12/site-packages (from tensorboard~=2.20.0->tensorflow) (12.0.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/lord/Desktop/-Proyecto-Integrador-II-Codelabs/.venv/lib/python3.12/site-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/lord/Desktop/-Proyecto-Integrador-II-Codelabs/.venv/lib/python3.12/site-packages (from tensorboard~=2.20.0->tensorflow) (3.1.4)
# Requirement already satisfied: rich in /home/lord/Desktop/-Proyecto-Integrador-II-Codelabs/.venv/lib/python3.12/site-packages (from keras) (14.2.0)
# Requirement already satisfied: namex in /home/lord/Desktop/-Proyecto-Integrador-II-Codelabs/.venv/lib/python3.12/site-packages (from keras) (0.1.0)
# Requirement already satisfied: optree in /home/lord/Desktop/-Proyecto-Integrador-II-Codelabs/.venv/lib/python3.12/site-packages (from keras) (0.18.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/lord/Desktop/-Proyecto-Integrador-II-Codelabs/.venv/lib/python3.12/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/lord/Desktop/-Proyecto-Integrador-II-Codelabs/.venv/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/lord/Desktop/-Proyecto-Integrador-II-Codelabs/.venv/lib/python3.12/site-packages (from matplotlib) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/lord/Desktop/-Proyecto-Integrador-II-Codelabs/.venv/lib/python3.12/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: pyparsing>=3 in /home/lord/Desktop/-Proyecto-Integrador-II-Codelabs/.venv/lib/python3.12/site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /home/lord/Desktop/-Proyecto-Integrador-II-Codelabs/.venv/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/lord/Desktop/-Proyecto-Integrador-II-Codelabs/.venv/lib/python3.12/site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: markupsafe>=2.1.1 in /home/lord/Desktop/-Proyecto-Integrador-II-Codelabs/.venv/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/lord/Desktop/-Proyecto-Integrador-II-Codelabs/.venv/lib/python3.12/site-packages (from rich->keras) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/lord/Desktop/-Proyecto-Integrador-II-Codelabs/.venv/lib/python3.12/site-packages (from rich->keras) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /home/lord/Desktop/-Proyecto-Integrador-II-Codelabs/.venv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# 2025-12-06 14:28:27.077235: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-12-06 14:28:27.757153: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-12-06 14:28:44.483374: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.

# %%
# ------------------------------  
# 1. Datos de entrenamiento (XOR)  
# ------------------------------  
# Entradas (todas las combinaciones posibles)  
X = np.array([  
    [0, 0],  
    [0, 1],  
    [1, 0],  
    [1, 1]  
])  
  
# Salidas esperadas (tabla XOR)  
y = np.array([  
    [0],  
    [1],  
    [1],  
    [0]  
])

# %%
# ------------------------------  
# 2. Definir el modelo  
# ------------------------------  
model = Sequential([  
    Input(shape=(2,)),            # 2 entradas (x1, x2)  
    Dense(4, activation="relu"),  # capa oculta con 4 neuronas ReLU  
    Dense(1, activation="sigmoid") # salida con activación Sigmoid  
])

# ------------------------------  
# 3. Compilar el modelo  
# ------------------------------  
model.compile(  
    optimizer="adam",  
    loss="binary_crossentropy",  
    metrics=["accuracy"]  
)
# optimizer: cómo aprende la red (Adam ajusta los pesos inteligentemente).
# loss: qué tan mal lo está haciendo en cada predicción (Binary Crossentropy mide error binario).  
# metrics: cómo medimos el rendimiento (Accuracy muestra el % de aciertos).
# Out:
# 2025-12-06 14:29:29.366011: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)

# %%
# ------------------------------  
# 4. Entrenar el modelo  
# ------------------------------  
history = model.fit(  
    X, y,  
    epochs=500,       # muchas épocas porque XOR no es lineal  
    verbose=0         # 0 = sin logs, cámbialo a 1 para ver entrenamiento  
)

# %%
# ------------------------------  
# 5. Evaluar y predecir  
# ------------------------------  
print("\nEvaluación final:")  
loss, acc = model.evaluate(X, y, verbose=0)  
print(f"Loss: {loss:.3f}, Accuracy: {acc:.3f}")  
  
print("\nPredicciones XOR:")  
for a, b in X:  
    pred = model.predict(np.array([[a, b]]), verbose=0)  
    print(f"{a} XOR {b} = {round(pred.item(), 3)}")
# Out:
# Evaluación final:
# Loss: 0.499, Accuracy: 1.000
#
# Predicciones XOR:
# 0 XOR 0 = 0.405
# 0 XOR 1 = 0.578
# 1 XOR 0 = 0.752
# 1 XOR 1 = 0.474
